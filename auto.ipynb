# %%
# 行业热点选择板块，板块里面筛选股票
import akshare as ak
import pandas as pd
# 关注排行榜
# stock_hot_follow_xq_df = ak.stock_hot_follow_xq(symbol="最热门")
# 讨论排行榜
# stock_hot_tweet_xq_df = ak.stock_hot_tweet_xq(symbol="最热门")
# 交易排行榜
stock_hot_deal_xq_df = ak.stock_hot_deal_xq(symbol="最热门")
# 人气榜-A股
stock_hot_rank_em_df = ak.stock_hot_rank_em()
# 飙升榜-A股
stock_hot_up_em_df = ak.stock_hot_up_em()
# Out:
# /home/liubei/miniconda3/envs/turtle/lib/python3.12/site-packages/py_mini_racer/py_mini_racer.py:15: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
#   0%|          | 0/28 [00:00<?, ?it/s]

# %%
stock_hot_up_em_df.head(10)
# Out:
#    排名较昨日变动  当前排名        代码  股票名称    最新价       涨跌额    涨跌幅
# 0     4873   208  SZ301222  浙江恒威  35.01  5.149971  14.71
# 1     4773   514  SZ920748  路桥信息  47.27  5.941839  12.57
# 2     4602   515  SZ301581  黄山谷捷  51.74  3.797716   7.34
# 3     4478   691  SH688576  西山科技  86.00  8.806400  10.24
# 4     4291    87  SH603630  拉芳家化  21.33  2.135133  10.01
# 5     4179   705  SH605158  华达新材   8.81  0.385878   4.38
# 6     4139   516  SZ301210  金杨精密  38.79  2.199393   5.67
# 7     4112   651  SH603983  丸美生物  33.00  1.636800   4.96
# 8     4042   104  SH600156  华升股份   9.03  0.902097   9.99
# 9     3994  1456  SZ920123  芭薇股份  15.98  1.043494   6.53

# %%
stock_hot_deal_xq_df=stock_hot_deal_xq_df.rename(columns={"股票代码":"代码","股票简称":"股票名称"})

# %%
stock_hot_rank_em_df
# Out:
#     当前排名        代码  股票名称     最新价        涨跌额    涨跌幅
# 0      1  SZ002506  协鑫集成    4.16   0.418080  10.05
# 1      2  SZ002342  巨力索具   18.88   1.361248   7.21
# 2      3  SZ000592  平潭发展   11.83   1.188915  10.05
# 3      4  SH601212  白银有色   10.22  -1.026088 -10.04
# 4      5  SZ002131  利欧股份    8.82  -0.418950  -4.75
# ..   ...       ...   ...     ...        ...    ...
# 95    96  SZ002865  钧达股份  102.86 -10.286000 -10.00
# 96    97  SZ301636  泽润新能   92.60   3.241000   3.50
# 97    98  SZ300136  信维通信   77.82  -1.019442  -1.31
# 98    99  SZ001337  四川黄金   46.05  -4.508295  -9.79
# 99   100  SH600796  钱江生化    7.29   0.725355   9.95
#
# [100 rows x 6 columns]

# %%
stock_hot_deal_xq_df
# Out:
#           股票代码  股票简称   关注      最新价
# 0     SH600519  贵州茅台  436  1555.00
# 1     SZ002594   比亚迪  249    90.11
# 2     SH600887  伊利股份  244    27.21
# 3     SH600036  招商银行  228    39.71
# 4     SH601919  中远海控  211    14.59
# ...        ...   ...  ...      ...
# 5554  SH603689  皖天然气    0     8.42
# 5555  SH603722   阿科力    0    38.31
# 5556  SZ300906   日月明    0    35.48
# 5557  SZ002259  升达林业    0     5.90
# 5558  SH688613  奥精医疗    0    22.19
#
# [5559 rows x 4 columns]

# %%
import pandas as pd

df = pd.merge(stock_hot_deal_xq_df.head(200), stock_hot_rank_em_df.head(200), how='inner')
df
# Out:
#         股票代码  股票简称   关注      最新价  当前排名        代码   股票名称        涨跌额    涨跌幅
# 0   SH600519  贵州茅台  436  1555.00    10  SH600519   贵州茅台  30.633500   1.97
# 1   SZ300308  中际旭创  140   561.99    90  SZ300308   中际旭创   2.023164   0.36
# 2   SZ300059  东方财富  133    22.93    41  SZ300059   东方财富   0.038981   0.17
# 3   SH601138  工业富联  129    53.88    71  SH601138   工业富联   0.474144   0.88
# 4   SH601899  紫金矿业  121    37.45    39  SH601899   紫金矿业  -1.636565  -4.37
# 5   SZ000547  航天发展   99    32.00     6  SZ000547   航天发展  -0.492800  -1.54
# 6   SZ002050  三花智控   93    50.09    85  SZ002050   三花智控  -1.522736  -3.04
# 7   SH603993  洛阳钼业   89    22.17    72  SH603993   洛阳钼业  -1.405578  -6.34
# 8   SH600089  特变电工   80    27.63    45  SH600089   特变电工  -1.395315  -5.05
# 9   SZ300058  蓝色光标   75    19.13    16  SZ300058   蓝色光标  -1.101888  -5.76
# 10  SH600410  华胜天成   73    21.89    68  SH600410   华胜天成   0.019701   0.09
# 11  SZ002131  利欧股份   72     8.82     5  SZ002131   利欧股份  -0.418950  -4.75
# 12  SZ002165   红宝丽   70    12.91    33  SZ002165  红 宝 丽  -1.106387  -8.57
# 13  SH601012  隆基绿能   69    18.23    63  SH601012   隆基绿能  -1.019057  -5.59
# 14  SZ300251  光线传媒   66    20.84    30  SZ300251   光线传媒   1.875600   9.00
# 15  SZ000592  平潭发展   63    11.83     3  SZ000592   平潭发展   1.188915  10.05
# 16  SZ300136  信维通信   62    77.82    98  SZ300136   信维通信  -1.019442  -1.31
# 17  SZ002163  海南发展   59    17.89    51  SZ002163   海南发展   0.805050   4.50
# 18  SH600118  中国卫星   51    92.23    83  SH600118   中国卫星  -4.989643  -5.41
# 19  SH601933  永辉超市   50     4.75    54  SH601933   永辉超市   0.219925   4.63
# 20  SH601162  天风证券   49     4.16     1  SZ002506   协鑫集成   0.418080  10.05
# 21  SZ002716  湖南白银   49    13.90    12  SZ002716   湖南白银  -1.385830  -9.97
# 22  SH600986  浙文互联   48    15.52     7  SH600986   浙文互联   0.743408   4.79
# 23  SZ000981  山子高科   46     4.82    48  SZ000981   山子高科  -0.300286  -6.23
# 24  SZ300300  海峡创新   45    14.52    15  SZ300300   海峡创新   2.904000  20.00
# 25  SZ002195  岩山科技   44     9.93    49  SZ002195   岩山科技  -0.157887  -1.59
# 26  SH600879  航天电子   44    26.09    64  SH600879   航天电子  -0.365260  -1.40
# 27  SZ002155  湖南黄金   44    32.71    23  SZ002155   湖南黄金  -2.924274  -8.94
# 28  SZ300017  网宿科技   44    17.97    25  SZ300017   网宿科技   1.344156   7.48
# 29  SZ002413  雷科防务   42    14.65    35  SZ002413   雷科防务   0.454150   3.10
# 30  SZ002702  海欣食品   42     7.69    37  SZ002702   海欣食品   0.769769  10.01
# 31  SH603778  国晟科技   42    16.80    42  SH603778   国晟科技   0.643440   3.83
# 32  SH601212  白银有色   41    10.22     4  SH601212   白银有色  -1.026088 -10.04
# 33  SZ002654  万润科技   39    13.90    12  SZ002716   湖南白银  -1.385830  -9.97
# 34  SZ002202  金风科技   39    24.82    14  SZ002202   金风科技  -2.238764  -9.02
# 35  SZ300436   广生堂   38   131.02    92  SZ300436    广生堂  16.953988  12.94
# 36  SZ000630  铜陵有色   38     7.19    38  SZ000630   铜陵有色  -0.441466  -6.14

# %%
from agents.planAgent import PlanAgent
from loguru import logger
import sys

logger.remove()                                     # 去掉默认全局配置
logger.add(sys.stderr, level="INFO") 

# 茅台太贵
exclude_symbol = ["600519"]

for _, item in df.iterrows():
    symbol = item.股票代码[2:]
    stock_info = ak.stock_individual_info_em(symbol)
    stock_info_dict = stock_info.set_index('item')['value'].to_dict()
    if stock_info_dict["总市值"] < 800 * 100000000:  # 市值大于一千亿
        continue
    if stock_info_dict["股票代码"].startswith("3"):
        continue
    if stock_info_dict["股票代码"] in exclude_symbol:
        continue
    print(stock_info)
    plan = PlanAgent()
    plan.set_symbol(symbol)
    plan.run(f"详细分析{symbol}行情情况，提供交易建议", human_in_loop=False)
    plan.send_allres_email()
# Out:
# 2026-01-14 00:29:13.456344683 [W:onnxruntime:Default, device_discovery.cc:164 DiscoverDevicesForPlatform] GPU device discovery failed: device_discovery.cc:89 ReadFileContents Failed to open file: "/sys/class/drm/card0/device/vendor"
# 2026-01-14 00:29:14.131 | INFO     | agents.planAgent:run:115 - planAgent：当前执行任务：详细分析603259行情情况，提供交易建议
#    item                value
# 0    最新                104.6
# 1  股票代码               603259
# 2  股票简称                 药明康德
# 3   总股本         2983757155.0
# 4   流通股         2473280246.0
# 5   总市值       312100998413.0
# 6  流通市值  258705113731.599976
# 7    行业                 医疗服务
# 8  上市时间             20180508
# ```json
# {
#   "main_task": "分析603259行情情况并提供交易建议",
#   "subtasks": [
#     {
#       "assigned_agent": "dataAgent",
#       "task_details": "查询603259的近期价格走势、成交量变化、技术指标（如MACD、RSI）以及市场表现"
#     },
#     {
#       "assigned_agent": "reportAgent",
#       "task_details": "获取并分析最近关于603259的券商研报，提取目标价区间、盈利预测和风险提示"
#     },
#     {
#       "assigned_agent": "investmentAgent",
#       "task_details": "结合603259的行情数据和研报分析结果，给出具体的买入、持有或卖出建议"
#     }
# 2026-01-14 00:29:21.916 | INFO     | agents.dataAgent:run:28 - dataAgent：当前执行任务：查询603259的近期价格走势、成交量变化、技术指标（如MACD、RSI）以及市场表现
# 2026-01-14 00:29:21.918 | INFO     | agents.dataAgent:run:32 - dataAgent：当前执行任务：603259 基本面数据
# 2026-01-14 00:29:21.919 | INFO     | agents.baseAgent:get_date_desc:135 - 收盘前，改成前一天
#   ]
# }
# ```
# 2026-01-14 00:29:26.273 | INFO     | agents.baseAgent:act_with_tools:71 - 执行函数方法：stock_individual_info_em,                                 参数：{"symbol": "603259"}
# 2026-01-14 00:29:26.335 | INFO     | agents.baseAgent:act_with_tools:71 - 执行函数方法：stock_financial_report_sina,                                 参数：{"symbol": "603259"}
# ### 药明康德（603259）基本面数据分析
#
# 以下是基于提供的财务数据对药明康德的基本面分析，涵盖资产、负债、利润和现金流等方面。
#
# ---
#
# #### **一、公司概况**
# - **股票代码**：603259
# - **股票简称**：药明康德
# - **行业**：医疗服务
# - **上市时间**：2018年5月8日
# - **总股本**：29.84亿股
# - **流通股**：24.73亿股
# - **总市值**：3121.01亿元
# - **流通市值**：2587.05亿元
#
# > **风险提示**：药明康德属于医疗服务行业，受政策监管、市场竞争及研发周期影响较大。投资者需关注行业政策变化及公司研发投入的持续性。
#
# ---
#
# #### **二、资产负债表分析**
# ##### 1. **资产结构**
# - **总资产**：9460.61亿元
# - **流动资产合计**：5381.23亿元（占比56.88%）
# - **非流动资产合计**：4079.38亿元（占比43.12%）
#
# **主要流动资产构成**：
# - **货币资金**：294.39亿元（占流动资产54.71%）
# - **交易性金融资产**：35.61亿元
# - **应收账款**：84.40亿元
# - **存货**：78.44亿元
#
# **主要非流动资产构成**：
# - **固定资产及清理合计**：194.11亿元
# - **长期股权投资**：19.43亿元
# - **其他非流动金融资产**：83.51亿元
#
# ##### 2. **负债结构**
# - **总负债**：2313.36亿元
# - **流动负债合计**：1943.83亿元（占比84.03%）
# - **非流动负债合计**：369.54亿元（占比15.97%）
#
# **主要负债构成**：
# - **短期借款**：52.82亿元
# - **应付账款**：22.73亿元
# - **合同负债**：25.66亿元
# - **租赁负债**：5.33亿元
#
# ##### 3. **所有者权益**
# - **股东权益合计**：7147.25亿元
# - **实收资本（或股本）**：29.66亿元
# - **资本公积**：317.37亿元
# - **未分配利润**：391.29亿元
#
# ---
#
# #### **三、利润表分析**
# ##### 1. **收入与成本**
# - **营业总收入**：328.57亿元
# - **营业总成本**：212.56亿元
# - **营业成本**：175.38亿元（占总收入53.38%）
#
# ##### 2. **盈利能力**
# - **营业利润**：150.66亿元
# - **净利润**：122.06亿元
# - **归属于母公司所有者的净利润**：120.76亿元
# - **基本每股收益**：4.25元
# - **稀释每股收益**：4.21元
#
# ##### 3. **费用结构**
# - **销售费用**：5.69亿元（占总收入1.73%）
# - **管理费用**：18.59亿元（占总收入5.66%）
# - **研发费用**：8.26亿元（占总收入2.51%）
#
# ---
#
# #### **四、现金流量表分析**
# ##### 1. **经营活动现金流**
# - **经营活动现金流入小计**：361.11亿元
# - **经营活动现金流出小计**：246.99亿元
# - **经营活动产生的现金流量净额**：114.13亿元
#
# ##### 2. **投资活动现金流**
# - **投资活动现金流入小计**：127.55亿元
# - **投资活动现金流出小计**：123.50亿元
# - **投资活动产生的现金流量净额**：4.05亿元
#
# ##### 3. **筹资活动现金流**
# - **筹资活动现金流入小计**：185.72亿元
# - **筹资活动现金流出小计**：181.49亿元
# - **筹资活动产生的现金流量净额**：4.23亿元
#
# ##### 4. **期末现金余额**
# - **期末现金及现金等价物余额**：254.76亿元
#
# ---
#
# #### **五、关键指标总结**
# | 指标类别         | 关键数据                  |
# |------------------|---------------------------|
# | 总资产          | 9460.61亿元              |
# | 总负债          | 2313.36亿元              |
# | 股东权益        | 7147.25亿元              |
# | 营业总收入      | 328.57亿元               |
# | 净利润          | 122.06亿元               |
# | 基本每股收益    | 4.25元                   |
# | 经营活动现金流  | 114.13亿元               |
#
# ---
#
# #### **六、综合评价**
# 1. **优势**：
#    - 公司资产规模庞大，货币资金充裕（294.39亿元），具备较强的抗风险能力。
#    - 盈利能力突出，净利润率高达37.15%，且每股收益较高（4.25元）。
#    - 经营活动现金流稳健，表明主营业务造血能力强。
#
# 2. **潜在风险**：
#    - 研发投入占比相对较低（2.51%），可能影响未来创新能力和竞争力。
#    - 非流动负债中租赁负债较高（5.33亿元），需关注长期偿债压力。
#
# 3. **行业特点**：
#    - 医疗服务行业受政策影响较大，需密切关注医保政策、药品审批等动态。
#
# > **免责声明**：以上信息基于公开数据整理，不构成投资建议。请结合专业机构分析进行决策。
# 2026-01-14 00:30:26.270 | INFO     | agents.dataAgent:run:32 - dataAgent：当前执行任务：603259 技术面数据
# 2026-01-14 00:30:26.271 | INFO     | agents.baseAgent:get_date_desc:135 - 收盘前，改成前一天
# 2026-01-14 00:30:35.349 | INFO     | agents.baseAgent:act_with_tools:71 - 执行函数方法：stock_zh_a_hist,                                 参数：{"symbol": "603259", "start_date": "20251013", "end_date": "20260113", "period": "daily", "adjust": ""}
# 2026-01-14 00:30:35.501 | INFO     | agents.baseAgent:act_with_tools:71 - 执行函数方法：get_indicators,                                 参数：{"symbol": "603259", "cur_date": "20260113", "data_range": 90}
# ### 技术面分析：股票代码 603259
#
# 以下是基于提供的技术指标数据对股票代码 603259 的技术面分析，涵盖价格趋势、动量指标、成交量和波动性等方面。
#
# ---
#
# #### **1. 价格趋势**
# - **均线（MA20）**：
#   - MA20 在 2025 年 11 月 11 日首次出现有效值为 98.9385，随后逐步下降至 2025 年 12 月 31 日的 91.511。
#   - 自 2026 年 1 月 5 日起，MA20 开始回升，从 91.76 上升至 2026 年 1 月 13 日的 93.785，表明短期价格趋势逐渐转强。
#   - **结论**：股价在 2025 年底经历了一段下行趋势后，近期开始企稳并呈现反弹迹象。
#
# ---
#
# #### **2. 动量指标**
# - **相对强弱指数（RSI14）**：
#   - RSI14 在 2025 年 11 月 4 日首次出现有效值为 42.94，处于中性偏弱区间（低于 50）。
#   - 2025 年 12 月 31 日，RSI14 降至 45.22，接近超卖区域（通常低于 30 视为超卖）。
#   - 自 2026 年 1 月 5 日起，RSI14 快速上升，从 56.58 增长至 2026 年 1 月 13 日的 74.11，进入强势区间（高于 70 视为超买）。
#   - **结论**：近期股价动量显著增强，市场情绪由悲观转向乐观。
#
# - **MACD 指标**：
#   - MACD 和信号线（MACDsig）在 2025 年 12 月 1 日首次出现有效值，分别为 -2.40 和 -2.97。
#   - MACD 从负值区域逐步回升，2026 年 1 月 6 日首次转正（0.028），并在 2026 年 1 月 13 日达到 1.957。
#   - MACD 直方图（MACDhist）持续扩大，从 2025 年 12 月 1 日的 0.565 增长至 2026 年 1 月 13 日的 1.293。
#   - **结论**：MACD 显示出强烈的买入信号，表明短期内股价可能继续上涨。
#
# ---
#
# #### **3. 成交量与资金流向**
# - **能量潮指标（OBV）**：
#   - OBV 在 2025 年 10 月 15 日至 2025 年 12 月 31 日期间波动较大，但整体呈下降趋势，从 2025 年 10 月 15 日的 421,801 下降至 2025 年 12 月 31 日的 1,223,030。
#   - 自 2026 年 1 月 5 日起，OBV 快速上升，从 1,951,650 增长至 2026 年 1 月 13 日的 4,355,140，显示资金流入明显增加。
#   - **结论**：近期成交量放大，资金流入强劲，支持股价上行。
#
# ---
#
# #### **4. 波动性**
# - **平均真实波幅（ATR14）**：
#   - ATR14 在 2025 年 11 月 4 日首次出现有效值为 4.28，随后逐步下降至 2025 年 12 月 31 日的 2.52。
#   - 自 2026 年 1 月 5 日起，ATR14 开始回升，从 2.74 增长至 2026 年 1 月 13 日的 3.22，表明市场波动性有所增加。
#   - **结论**：近期波动性上升，可能预示着价格将出现较大变动。
#
# ---
#
# #### **5. 综合分析**
# - **短期趋势**：股价在 2025 年底经历了一段调整期后，近期开始企稳并呈现反弹迹象。MA20 和 RSI14 均显示短期趋势向好。
# - **动量信号**：RSI14 和 MACD 均发出强烈的买入信号，表明市场情绪正在改善。
# - **资金流向**：OBV 显示资金流入显著增加，支持股价进一步上涨。
# - **波动性**：ATR14 上升表明市场波动性增加，投资者需警惕潜在的价格波动风险。
#
# ---
#
# #### **风险提示**
# - 股价近期波动性较高，投资者需注意市场情绪变化可能导致的价格回调。
# - RSI14 已进入超买区域（高于 70），需警惕短期内可能出现的技术性调整。
#
# ---
#
# #### **总结**
# 综合来看，股票代码 603259 的技术面显示短期内存在较强的上涨动能，但需关注超买信号和波动性风险。建议投资者
# 2026-01-14 00:31:34.661 | INFO     | agents.dataAgent:run:32 - dataAgent：当前执行任务：603259 行业与竞争数据
# 2026-01-14 00:31:34.662 | INFO     | agents.baseAgent:get_date_desc:135 - 收盘前，改成前一天
# 结合基本面和其他市场信息进行综合判断。
# 2026-01-14 00:31:36.884 | INFO     | agents.baseAgent:act_with_tools:71 - 执行函数方法：stock_individual_info_em,                                 参数：{"symbol": "603259"}
# 2026-01-14 00:31:37.024 | INFO     | agents.baseAgent:act_with_tools:71 - 执行函数方法：stock_board_industry_summary_ths,                                 参数：{"symbol": "603259"}
#   0%|          | 0/2 [00:00<?, ?it/s]
# ### 药明康德（603259）行业与竞争数据分析
#
# #### 一、公司基本信息
# - **股票代码**：603259
# - **股票简称**：药明康德
# - **行业**：医疗服务
# - **总股本**：29.84亿股
# - **流通股**：24.73亿股
# - **总市值**：3121.01亿元
# - **流通市值**：2587.05亿元
# - **上市时间**：2018年5月8日
#
# ---
#
# #### 二、行业整体表现
# 根据提供的行业数据：
# - **板块**：医疗服务
# - **涨跌幅**：+4.44%
# - **总成交量**：2217.39万手
# - **总成交额**：577.59亿元
# - **净流入**：-18.63亿元（资金呈净流出状态）
# - **上涨家数**：45家
# - **下跌家数**：9家
# - **均价**：26.05元
#
# **分析**：
# 1. 医疗服务板块整体表现较强，涨跌幅为+4.44%，表明市场对该行业的关注度较高。
# 2. 板块内上涨家数远多于下跌家数（45:9），说明行业整体趋势向好。
# 3. 净流入为负值（-18.63亿元），可能反映出部分资金在高位获利了结，需警惕短期波动风险。
#
# ---
#
# #### 三、行业领涨股对比
# - **领涨股**：诺思格
# - **领涨股最新价**：76.48元
# - **领涨股涨跌幅**：+20.01%
#
# **药明康德与领涨股对比**：
# | 指标            | 药明康德       | 领涨股（诺思格） |
# |-----------------|---------------|-----------------|
# | 最新价         | 104.6元       | 76.48元         |
# | 涨跌幅         | 数据未提供    | +20.01%         |
# | 总市值         | 3121.01亿元   | 数据未提供      |
# | 流通市值       | 2587.05亿元   | 数据未提供      |
#
# **分析**：
# 1. 药明康德的股价（104.6元）高于领涨股诺思格（76.48元），但缺乏当日涨跌幅数据，无法直接比较短期表现。
# 2. 药明康德作为行业龙头，市值规模远超领涨股，具备更强的市场影响力和抗风险能力。
# 3. 领涨股诺思格当日涨幅高达20.01%，可能受到特定利好消息推动，但需注意其市值较小，波动性较大。
#
# ---
#
# #### 四、药明康德的竞争优势与风险提示
# **竞争优势**：
# 1. **行业龙头地位**：药明康德是医疗服务领域的龙头企业，总市值超过3000亿元，具备较强的市场竞争力。
# 2. **高流通性**：流通市值接近2600亿元，流动性较好，适合大资金进出。
# 3. **长期增长潜力**：医疗服务行业需求稳定，随着人口老龄化和医疗技术进步，行业前景广阔。
#
# **风险提示**：
# 1. **资金流出压力**：医疗服务板块当日净流入为负值（-18.63亿元），可能对药明康德等权重股造成短期压力。
# 2. **高估值风险**：药明康德当前总市值超过3000亿元，需警惕高估值回调风险。
# 3. **行业竞争加剧**：尽管药明康德处于领先地位，但行业内其他公司（如诺思格）可能通过创新或并购快速崛起，形成竞争威胁。
#
# ---
#
# #### 五、总结
# 药明康德作为医疗服务行业的龙头企业，具备较强的市场地位和长期发展潜力。然而，投资者需关注以下几点：
# 1. 行业整体资金流向（当日净流出-18.63亿元）；
# 2. 高估值可能带来的回调风险；
# 3. 行业内中小市值公司（如诺思格）的快速崛起对竞争格局的影响。
#
# **特别提醒**：本分析仅基于公开数据，不构成投资建议，请结合专业机构分析和个人风险承受能力
# 2026-01-14 00:32:31.933 | INFO     | agents.planAgent:act:111 - ***************************************************************************************************
# 2026-01-14 00:32:31.935 | INFO     | agents.reportAgent:run:23 - reportAgent：当前执行任务：获取并分析最近关于603259的券商研报，提取目标价区间、盈利预测和风险提示
# 2026-01-14 00:32:31.936 | INFO     | agents.baseAgent:get_date_desc:135 - 收盘前，改成前一天
# 进行决策。
#   0%|          | 0/3 [00:00<?, ?it/s]
# 2026-01-14 00:33:13.711 | INFO     | agents.baseAgent:act_with_tools_stepbystep:117 - No tool calls were made by the model.
# ### 【个股研报总结】药明康德（代码：603259）
# - **核心结论**：
#   药明康德业绩增长强劲，小分子D&M和TIDES业务驱动收入提升，上调全年指引。公司聚焦CRDMO业务模式，剥离非核心业务有助于利润率提升。
#
# - **支撑依据**：
#   - **财务表现**：
#     - 2025年前三季度持续经营收入同比增长22.5%，经调整Non-IFRS归母净利润同比增长43.4%（浦银国际数据）。
#     - 202
